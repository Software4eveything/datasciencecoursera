# %%
import pandas as pd

# %%
file_name ='https://docs.google.com/spreadsheets/d/e/2PACX-1vSX7IQrG6UNyBk-08erUambZd5aBtzWjSbLPf_mWFag_91TBbi_YFlalhqNByIP7Y0HRg81F2Ov8Va5/pub?output=csv'
df=pd.read_csv(file_name)

# %%
df.head()
# Out:
#         id        name  id_2  startDay startTime     endDay   endTime   Car  \
# 0  1040000  Montgomery    -1    Monday   5:00:00  Wednesday  10:00:00  1.40
# 1  1040010       Black    -1    Monday  10:00:00     Friday  15:00:00  1.40
# 2  1040020     Emerald    -1  Thursday  15:00:00     Friday  19:00:00  1.65
# 3  1040030       Foley    -1    Monday  19:00:00     Friday  23:59:59  2.75
# 4  1530000     Antioch    -1  Saturday   0:00:00     Sunday  23:59:59  6.00
#
#    Hov2  Hov3  ...  ableSec3AxlesDualTire  ableSec4AxlesDualTire  \
# 0  1.40  1.40  ...                     -1                     -1
# 1  1.40  1.40  ...                     -1                     -1
# 2  1.65  1.65  ...                     -1                     -1
# 3  2.75  2.75  ...                     -1                     -1
# 4  6.00  6.00  ...                     -1                     -1
#
#    ableSec2AxlesTNC  ableSec2AxlesTNCPool  ableSec2AxlesTaxi  \
# 0                -1                    -1                 -1
# 1                -1                    -1                 -1
# 2                -1                    -1                 -1
# 3                -1                    -1                 -1
# 4                -1                    -1                 -1
#
#    ableSec2AxlesTaxiPool  able22AxlesAuto  able23AxlesAuto  \
# 0                     -1                6                1
# 1                     -1                6                1
# 2                     -1                6                1
# 3                     -1                6                2
# 4                     -1                6                1
#
#                           road      date
# 0        Alabama River Parkway  ########
# 1        Black Warrior Parkway  ########
# 2  Emerald Mountain Expressway  ########
# 3          Foley Beach Express  ########
# 4                       SR 160  ########
#
# [5 rows x 37 columns]

# %%
new_df = df.copy()

# %%
 new_df.sort_values(by=['Hov2'], ascending=False)
# Out:
#            id               name  id_2  startDay startTime     endDay  \
# 6908  1031032            Highway    -1    Monday   5:00:00  Wednesday
# 6905  1031026            Highway    -1    Monday  19:00:00     Friday
# 6907  1031030  Darlington-Clarke    -1  Saturday   0:00:00     Sunday
# 6904  1031024            Highway    -1    Monday  15:00:00     Friday
# 6906  1031028     57/Bowmanville    -1  Saturday   0:00:00     Sunday
# ...       ...                ...   ...       ...       ...        ...
# 2991  1165012               From    -1    Monday   0:00:00     Friday
# 2990  1165011              South    -1  Saturday   0:00:00     Sunday
# 2989  1165010                 W.    -1    Monday  19:00:00     Friday
# 2497  1148000               From    -1    Monday   0:00:00     Friday
# 2490  1148000               From    -1  Saturday   0:00:00     Sunday
#
#        endTime    Car   Hov2   Hov3  ...  ableSec3AxlesDualTire  \
# 6908  10:00:00  75.19  75.19  75.19  ...                     -1
# 6905  23:59:59  74.11  74.11  74.11  ...                     -1
# 6907  23:59:59  73.69  73.69  73.69  ...                     -1
# 6904  19:00:00  72.86  72.86  72.86  ...                     -1
# 6906  23:59:59  71.73  71.73  71.73  ...                     -1
# ...        ...    ...    ...    ...  ...                    ...
# 2991   5:00:00  -1.00  -1.00  -1.00  ...                     -1
# 2990  23:59:59  -1.00  -1.00  -1.00  ...                     -1
# 2989  23:59:59  -1.00  -1.00  -1.00  ...                     -1
# 2497   5:00:00  -1.00  -1.00   0.00  ...                     -1
# 2490  23:59:59  -1.00  -1.00   0.00  ...                     -1
#
#       ableSec4AxlesDualTire  ableSec2AxlesTNC  ableSec2AxlesTNCPool  \
# 6908                     -1                -1                    -1
# 6905                     -1                -1                    -1
# 6907                     -1                -1                    -1
# 6904                     -1                -1                    -1
# 6906                     -1                -1                    -1
# ...                     ...               ...                   ...
# 2991                     -1                -1                    -1
# 2990                     -1                -1                    -1
# 2989                     -1                -1                    -1
# 2497                     -1                -1                    -1
# 2490                     -1                -1                    -1
#
#       ableSec2AxlesTaxi  ableSec2AxlesTaxiPool  able22AxlesAuto  \
# 6908                 -1                     -1                6
# 6905                 -1                     -1                6
# 6907                 -1                     -1                6
# 6904                 -1                     -1                6
# 6906                 -1                     -1                6
# ...                 ...                    ...              ...
# 2991                 -1                     -1                6
# 2990                 -1                     -1                6
# 2989                 -1                     -1                6
# 2497                 -1                     -1                6
# 2490                 -1                     -1                6
#
#       able23AxlesAuto                                road      date
# 6908                1                             ETR 407  ########
# 6905                1                             ETR 407  ########
# 6907                1                             ETR 407  ########
# 6904                2                             ETR 407  ########
# 6906                1                             ETR 407  ########
# ...               ...                                 ...       ...
# 2991                1  HOT US 59 South/ Southwest Freeway  ########
# 2990                2  HOT US 59 South/ Southwest Freeway  ########
# 2989                2  HOT US 59 South/ Southwest Freeway  ########
# 2497                2      HOT US 290 / Northwest Freeway  ########
# 2490                2      HOT US 290 / Northwest Freeway  ########
#
# [7035 rows x 37 columns]

# %%
new_df.drop_duplicates(subset=['id', 'id_2'], keep='first', inplace=True)

# %%
new_df.sort_values(by=['id', 'id_2'], ascending=[True, True], inplace=True)

# %%
new_df.to_csv('task_1.csv', index=False)

# %%
new_df.head()
# Out:
#            id            name  id_2  startDay startTime     endDay   endTime  \
# 1408  1010000  Fargo-Moorhead    -1    Monday  19:00:00     Friday  23:59:59
# 1407  1011000   International    -1    Monday  15:00:00     Friday  19:00:00
# 1410  1012000        Bellevue    -1  Saturday   0:00:00     Sunday  23:59:59
# 1411  1012002     Plattsmouth    -1    Monday   5:00:00  Wednesday  10:00:00
# 1412  1013000          Valley    -1    Monday  10:00:00     Friday  15:00:00
#
#       Car  Hov2  Hov3  ...  ableSec3AxlesDualTire  ableSec4AxlesDualTire  \
# 1408 -1.0  -1.0  -1.0  ...                     -1                     -1
# 1407 -1.0  -1.0  -1.0  ...                     -1                     -1
# 1410 -1.0  -1.0  -1.0  ...                     -1                     -1
# 1411 -1.0  -1.0  -1.0  ...                     -1                     -1
# 1412 -1.0  -1.0  -1.0  ...                     -1                     -1
#
#       ableSec2AxlesTNC  ableSec2AxlesTNCPool  ableSec2AxlesTaxi  \
# 1408                -1                    -1                 -1
# 1407                -1                    -1                 -1
# 1410                -1                    -1                 -1
# 1411                -1                    -1                 -1
# 1412                -1                    -1                 -1
#
#       ableSec2AxlesTaxiPool  able22AxlesAuto  able23AxlesAuto  \
# 1408                     -1                6                1
# 1407                     -1                6                2
# 1410                     -1                6                1
# 1411                     -1                6                1
# 1412                     -1                6                1
#
#                                     road      date
# 1408          Fargo-Moorhead Toll Bridge  ########
# 1407  International Falls / Fort Frances  ########
# 1410                     Bellevue Bridge  ########
# 1411                  Plattsmouth Bridge  ########
# 1412                 Valley of Fire Road  ########
#
# [5 rows x 37 columns]
